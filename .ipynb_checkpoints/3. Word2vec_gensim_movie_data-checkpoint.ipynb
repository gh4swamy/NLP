# %% [markdown]
# # Load Gensim Library

# %%
import pandas as pd
import re, string
import gensim
import logging
# Out:
# C:\Users\swamy\Anaconda3\envs\tfdeeplearning\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # Load Text Data

# %%
df = pd.read_csv('unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %% [markdown]
# # Function to Clean up data

# %%
def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %% [markdown]
# Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)

# %%
df.head()
# Out:
#           id                                             review  \
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...
#
#                                         clean_review
# 0  watching time chasers it obvious that it was m...
# 1  i saw this film about years ago and remember i...
# 2  minor spoilers br br in new york joan barnard ...
# 3  i went to see this film with a great deal of e...
# 4  yes i agree with everyone on this site this mo...

# %% [markdown]
# # Convert Each Review to a Word List before feeding to Word2Vec

# %%
documents = []

# %%
for doc in df['clean_review']:
    documents.append(doc.split(' '))

# %%
documents[0]
# Out:
# ['watching',
#  'time',
#  'chasers',
#  'it',
#  'obvious',
#  'that',
#  'it',
#  'was',
#  'made',
#  'by',
#  'a',
#  'bunch',
#  'of',
#  'friends',
#  'maybe',
#  'they',
#  'were',
#  'sitting',
#  'around',
#  'one',
#  'day',
#  'in',
#  'film',
#  'school',
#  'and',
#  'said',
#  'hey',
#  'let',
#  's',
#  'pool',
#  'our',
#  'money',
#  'together',
#  'and',
#  'make',
#  'a',
#  'really',
#  'bad',
#  'movie',
#  'or',
#  'something',
#  'like',
#  'that',
#  'what',
#  'ever',
#  'they',
#  'said',
#  'they',
#  'still',
#  'ended',
#  'up',
#  'making',
#  'a',
#  'really',
#  'bad',
#  'movie',
#  'dull',
#  'story',
#  'bad',
#  'script',
#  'lame',
#  'acting',
#  'poor',
#  'cinematography',
#  'bottom',
#  'of',
#  'the',
#  'barrel',
#  'stock',
#  'music',
#  'etc',
#  'all',
#  'corners',
#  'were',
#  'cut',
#  'except',
#  'the',
#  'one',
#  'that',
#  'would',
#  'have',
#  'prevented',
#  'this',
#  'film',
#  's',
#  'release',
#  'life',
#  's',
#  'like',
#  'that']

# %%
len(documents)
# Out:
# 50000

# %% [markdown]
# # Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2018-05-04 14:19:45,682 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-05-04 14:19:45,689 : INFO : collecting all words and their counts
# 2018-05-04 14:19:45,694 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-05-04 14:19:46,741 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2018-05-04 14:19:47,749 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2018-05-04 14:19:48,959 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2018-05-04 14:19:49,951 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2018-05-04 14:19:50,962 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2018-05-04 14:19:50,962 : INFO : Loading a fresh vocabulary
# 2018-05-04 14:19:51,817 : INFO : min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2018-05-04 14:19:51,822 : INFO : min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2018-05-04 14:19:52,083 : INFO : deleting the raw counts dictionary of 100479 items
# 2018-05-04 14:19:52,108 : INFO : sample=0.001 downsamples 49 most-common words
# 2018-05-04 14:19:52,113 : INFO : downsampling leaves estimated 8817283 word corpus (74.0% of prior 11910457)
# 2018-05-04 14:19:52,363 : INFO : estimated required memory for 28322 words and 50 dimensions: 25489800 bytes
# 2018-05-04 14:19:52,368 : INFO : resetting layer weights
# 2018-05-04 14:19:53,439 : INFO : training model with 4 workers on 28322 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-05-04 14:19:54,517 : INFO : EPOCH 1 - PROGRESS: at 4.01% examples, 345567 words/s, in_qsize 8, out_qsize 0
# 2018-05-04 14:19:55,551 : INFO : EPOCH 1 - PROGRESS: at 8.68% examples, 367757 words/s, in_qsize 8, out_qsize 0
# 2018-05-04 14:19:56,552 : INFO : EPOCH 1 - PROGRESS: at 11.73% examples, 334362 words/s, in_qsize 7, out_qsize 0
# 2018-05-04 14:19:57,560 : INFO : EPOCH 1 - PROGRESS: at 16.01% examples, 343295 words/s, in_qsize 7, out_qsize 0
# 2018-05-04 14:19:58,611 : INFO : EPOCH 1 - PROGRESS: at 20.48% examples, 349244 words/s, in_qsize 8, out_qsize 0
# 2018-05-04 14:19:59,622 : INFO : EPOCH 1 - PROGRESS: at 24.68% examples, 352608 words/s, in_qsize 7, out_qsize 0
# 2018-05-04 14:20
lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# (28322, 50)

# %%
model.wv.vocab
# Out:
# {'salesman': <gensim.models.keyedvectors.Vocab at 0x1dd3846bf98>,
#  'groom': <gensim.models.keyedvectors.Vocab at 0x1dd368daba8>,
#  'letting': <gensim.models.keyedvectors.Vocab at 0x1dd36b98128>,
#  'unshaven': <gensim.models.keyedvectors.Vocab at 0x1dd36890d30>,
#  'begun': <gensim.models.keyedvectors.Vocab at 0x1dd368da5c0>,
#  'willis': <gensim.models.keyedvectors.Vocab at 0x1dd36b6c2e8>,
#  'darnell': <gensim.models.keyedvectors.Vocab at 0x1dd36890cc0>,
#  'geek': <gensim.models.keyedvectors.Vocab at 0x1dd368da438>,
#  'overly': <gensim.models.keyedvectors.Vocab at 0x1dd36a838d0>,
#  'benton': <gensim.models.keyedvectors.Vocab at 0x1dd36b98438>,
#  'blissfully': <gensim.models.keyedvectors.Vocab at 0x1dd368da128>,
#  'rally': <gensim.models.keyedvectors.Vocab at 0x1dd368e4400>,
#  'covering': <gensim.models.keyedvectors.Vocab at 0x1dd36b98160>,
#  'inspiring': <gensim.models.keyedvectors.Vocab at 0x1dd36b98550>,
#  'ruin': <gensim.models.keyedvectors.Vocab at 0x1dd36890d68>,
#  'boarding': <gensim.models.keyedvectors.Vocab at 0x1dd368e45c0>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1dd384c6be0>,
#  'blackness': <gensim.models.keyedvectors.Vocab at 0x1dd36a969b0>,
#  'adapting': <gensim.models.keyedvectors.Vocab at 0x1dd36890da0>,
#  'wand': <gensim.models.keyedvectors.Vocab at 0x1dd36890e10>,
#  'larry': <gensim.models.keyedvectors.Vocab at 0x1dd36b98198>,
#  'plutonium': <gensim.models.keyedvectors.Vocab at 0x1dd368e46d8>,
#  'meandering': <gensim.models.keyedvectors.Vocab at 0x1dd368e4588>,
#  'ois': <gensim.models.keyedvectors.Vocab at 0x1dd36890898>,
#  'unyielding': <gensim.models.keyedvectors.Vocab at 0x1dd3690e9e8>,
#  'astonishment': <gensim.models.keyedvectors.Vocab at 0x1dd3690e6a0>,
#  'unkind': <gensim.models.keyedvectors.Vocab at 0x1dd36b981d0>,
#  'seats': <gensim.models.keyedvectors.Vocab at 0x1dd3690e7b8>,
#  'porky': <gensim.models.keyedvectors.Vocab at 0x1dd36890860>,
#  'wendell': <gensim.models.keyedvectors.Vocab at 0x1dd368908d0>,
#  'interconnected': <gensim.models.keyedvectors.Vocab at 0x1dd36a96a20>,
#  'runners': <gensim.models.keyedvectors.Vocab at 0x1dd36cac2e8>,
#  'ants': <gensim.models.keyedvectors.Vocab at 0x1dd36b98208>,
#  'penetrating': <gensim.models.keyedvectors.Vocab at 0x1dd36bf7320>,
#  'slug': <gensim.models.keyedvectors.Vocab at 0x1dd36b98240>,
#  'paradiso': <gensim.models.keyedvectors.Vocab at 0x1dd3690e588>,
#  'sidewalks': <gensim.models.keyedvectors.Vocab at 0x1dd36b98be0>,
#  'shrews': <gensim.models.keyedvectors.Vocab at 0x1dd36b98c18>,
#  'ida': <gensim.models.keyedvectors.Vocab at 0x1dd3690e748>,
#  'hokey': <gensim.models.keyedvectors.Vocab at 0x1dd36b98278>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x1dd384b3240>,
#  'herb': <gensim.models.keyedvectors.Vocab at 0x1dd36890940>,
#  'churches': <gensim.models.keyedvectors.Vocab at 0x1dd36b982b0>,
#  'collect': <gensim.models.keyedvectors.Vocab at 0x1dd3846d278>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x1dd36b982e8>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x1dd36b98320>,
#  'julien': <gensim.models.keyedvectors.Vocab at 0x1dd3690e4a8>,
#  'impediment': <gensim.models.keyedvectors.Vocab at 0x1dd36b98358>,
#  'sensibly': <gensim.models.keyedvectors.Vocab at 0x1dd3690ea20>,
#  'obliged': <gensim.models.keyedvectors.Vocab at 0x1dd36a96a90>,
#  'jagger': <gensim.models.keyedvectors.Vocab at 0x1dd36bd7860>,
#  'unrest': <gensim.models.keyedvectors.Vocab at 0x1dd3690e550>,
#  'patriarch': <gensim.models.keyedvectors.Vocab at 0x1dd36b983c8>,
#  'hassle': <gensim.models.keyedvectors.Vocab at 0x1dd36890828>,
#  'crichton': <gensim.models.keyedvectors.Vocab at 0x1dd36a96ac8>,
#  'selleck': <gensim.models.keyedvectors.Vocab at 0x1dd36b984a8>,
#  'cain': <gensim.models.keyedvectors.Vocab at 0x1dd36a96b38>,
#  'ineffectual': <gensim.models.keyedvectors.Vocab at 0x1dd36890668>,
#  'pulp': <gensim.models.keyedvectors.Vocab at 0x1dd3690e780>,
#  'tweety': <gensim.models.keyedvectors.Vocab at 0x1dd3690e710>,
#  'prop': <gensim.models.keyedvectors.Vocab at 0x1dd3690ee80>,
#  'liberals': <gensim.models.keyedvectors.Vocab at 0x1dd36b98518>,
#  'streak': <gensim.models.keyedvectors.Vocab at 0x1dd36890710>,
#  'escapes': <gensim.models.keyedvectors.Vocab at 0x1dd38458e48>,
#  'nineteen': <gensim.models.keyedvectors.Vocab at 0x1dd36a96b70>,
#  'yourselves': <gensim.models.keyedvectors.Vocab at 0x1dd3690e198>,
#  'ambitious': <gensim.models.keyedvectors.Vocab at 0x1dd3690e7f0>,
#  'ilias': <gensim.models.keyedvectors.Vocab at 0x1dd3690a278>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x1dd3690e048>,
#  'ammunition': <gensim.models.keyedvectors.Vocab at 0x1dd36b98588>,
#  'ops': <gensim.models.keyedvectors.Vocab at 0x1dd3690ea58>,
#  'ditsy': <gensim.models.keyedvectors.Vocab at 0x1dd36b985c0>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1dd36b985f8>,
#  'photojournalist': <gensim.models.keyedvectors.Vocab at 0x1dd36890320>,
#  'virile': <gensim.models.keyedvectors.Vocab at 0x1dd36916160>,
#  'ackles': <gensim.models.keyedvectors.Vocab at 0x1dd36b98630>,
#  'boobs': <gensim.models.keyedvectors.Vocab at 0x1dd36b413c8>,
#  'downloaded': <gensim.models.keyedvectors.Vocab at 0x1dd36b98668>,
#  'candace': <gensim.models.keyedvectors.Vocab at 0x1dd3690e128>,
#  'ans': <gensim.models.keyedvectors.Vocab at 0x1dd369cd860>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x1dd36b986d8>,
#  'enraged': <gensim.models.keyedvectors.Vocab at 0x1dd3690e080>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x1dd36a96be0>,
#  'whim': <gensim.models.keyedvectors.Vocab at 0x1dd3690e160>,
#  'del': <gensim.models.keyedvectors.Vocab at 0x1dd368905c0>,
#  'yul': <gensim.models.keyedvectors.Vocab at 0x1dd36a96c18>,
#  'nerds': <gensim.models.keyedvectors.Vocab at 0x1dd36ca9390>,
#  'creates': <gensim.models.keyedvectors.Vocab at 0x1dd36890358>,
#  'broomfield': <gensim.models.keyedvectors.Vocab at 0x1dd368d29e8>,
#  'guns': <gensim.models.keyedvectors.Vocab at 0x1dd369e0d30>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x1dd36b98748>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1dd36b98780>,
#  'wit': <gensim.models.keyedvectors.Vocab at 0x1dd36b987b8>,
#  'meditative': <gensim.models.keyedvectors.Vocab at 0x1dd3690e240>,
#  'lease': <gensim.models.keyedvectors.Vocab at 0x1dd3690e0f0>,
#  'dreams': <gensim.models.keyedvectors.Vocab at 0x1dd36a96c88>,
#  'balk': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e4e0>,
#  'squabbling': <gensim.models.keyedvectors.Vocab at 0x1dd36890400>,
#  'traitors': <gensim.models.keyedvectors.Vocab at 0x1dd36b987f0>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x1dd36b00470>,
#  'module': <gensim.models.keyedvectors.Vocab at 0x1dd36aeab00>,
#  'mannequins': <gensim.models.keyedvectors.Vocab at 0x1dd368902b0>,
#  'slovenly': <gensim.models.keyedvectors.Vocab at 0x1dd36a96cc0>,
#  'classier': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e8d0>,
#  'underplaying': <gensim.models.keyedvectors.Vocab at 0x1dd36b98860>,
#  'wolf': <gensim.models.keyedvectors.Vocab at 0x1dd36a96cf8>,
#  'octane': <gensim.models.keyedvectors.Vocab at 0x1dd36a96d30>,
#  'spike': <gensim.models.keyedvectors.Vocab at 0x1dd36b988d0>,
#  'mehdi': <gensim.models.keyedvectors.Vocab at 0x1dd36a96d68>,
#  'prevents': <gensim.models.keyedvectors.Vocab at 0x1dd369e0d68>,
#  'ludivine': <gensim.models.keyedvectors.Vocab at 0x1dd3690ef60>,
#  'lookalike': <gensim.models.keyedvectors.Vocab at 0x1dd368900b8>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x1dd36b98908>,
#  'overacts': <gensim.models.keyedvectors.Vocab at 0x1dd36c927b8>,
#  'commanders': <gensim.models.keyedvectors.Vocab at 0x1dd36890278>,
#  'allowed': <gensim.models.keyedvectors.Vocab at 0x1dd36c236a0>,
#  'ruthlessness': <gensim.models.keyedvectors.Vocab at 0x1dd3690e208>,
#  'cotten': <gensim.models.keyedvectors.Vocab at 0x1dd368838d0>,
#  'recap': <gensim.models.keyedvectors.Vocab at 0x1dd36ba00b8>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x1dd36b98940>,
#  'mythos': <gensim.models.keyedvectors.Vocab at 0x1dd3690ef28>,
#  'probes': <gensim.models.keyedvectors.Vocab at 0x1dd36a96dd8>,
#  'sane': <gensim.models.keyedvectors.Vocab at 0x1dd3690e278>,
#  'rani': <gensim.models.keyedvectors.Vocab at 0x1dd3690eb38>,
#  'jaspers': <gensim.models.keyedvectors.Vocab at 0x1dd384b1588>,
#  'gratification': <gensim.models.keyedvectors.Vocab at 0x1dd384ac320>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x1dd36a96e10>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x1dd36b989b0>,
#  'dismiss': <gensim.models.keyedvectors.Vocab at 0x1dd36a96e48>,
#  'connecticut': <gensim.models.keyedvectors.Vocab at 0x1dd36a96e80>,
#  'cynically': <gensim.models.keyedvectors.Vocab at 0x1dd36a96eb8>,
#  'yea': <gensim.models.keyedvectors.Vocab at 0x1dd36883e80>,
#  'libre': <gensim.models.keyedvectors.Vocab at 0x1dd36ca93c8>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x1dd36a96ef0>,
#  'howlers': <gensim.models.keyedvectors.Vocab at 0x1dd36b989e8>,
#  'observers': <gensim.models.keyedvectors.Vocab at 0x1dd36a96f28>,
#  'gentleman': <gensim.models.keyedvectors.Vocab at 0x1dd36a96f60>,
#  'footsteps': <gensim.models.keyedvectors.Vocab at 0x1dd3690eef0>,
#  'uninspiring': <gensim.models.keyedvectors.Vocab at 0x1dd36a96f98>,
#  'voyeurism': <gensim.models.keyedvectors.Vocab at 0x1dd36b98a58>,
#  'tyrannical': <gensim.models.keyedvectors.Vocab at 0x1dd36a96fd0>,
#  'dumbed': <gensim.models.keyedvectors.Vocab at 0x1dd36a99048>,
#  'tits': <gensim.models.keyedvectors.Vocab at 0x1dd36a99080>,
#  'proposition': <gensim.models.keyedvectors.Vocab at 0x1dd38444f28>,
#  'gta': <gensim.models.keyedvectors.Vocab at 0x1dd369fc7b8>,
#  'simpleton': <gensim.models.keyedvectors.Vocab at 0x1dd38493358>,
#  'cloudy': <gensim.models.keyedvectors.Vocab at 0x1dd3690ebe0>,
#  'creations': <gensim.models.keyedvectors.Vocab at 0x1dd36a990b8>,
#  'swamp': <gensim.models.keyedvectors.Vocab at 0x1dd36936eb8>,
#  'chandler': <gensim.models.keyedvectors.Vocab at 0x1dd3690eb70>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x1dd36a990f0>,
#  'baggage': <gensim.models.keyedvectors.Vocab at 0x1dd3690ec88>,
#  'jungle': <gensim.models.keyedvectors.Vocab at 0x1dd3690eba8>,
#  'cadavers': <gensim.models.keyedvectors.Vocab at 0x1dd3690ecc0>,
#  'caters': <gensim.models.keyedvectors.Vocab at 0x1dd36883860>,
#  'disable': <gensim.models.keyedvectors.Vocab at 0x1dd384a6470>,
#  'overtime': <gensim.models.keyedvectors.Vocab at 0x1dd36ba30f0>,
#  'campaigns': <gensim.models.keyedvectors.Vocab at 0x1dd3690ec18>,
#  'culminating': <gensim.models.keyedvectors.Vocab at 0x1dd36a99160>,
#  'enhances': <gensim.models.keyedvectors.Vocab at 0x1dd3690ec50>,
#  'escapist': <gensim.models.keyedvectors.Vocab at 0x1dd3690ed68>,
#  'defining': <gensim.models.keyedvectors.Vocab at 0x1dd36883898>,
#  'floppy': <gensim.models.keyedvectors.Vocab at 0x1dd36883978>,
#  'setup': <gensim.models.keyedvectors.Vocab at 0x1dd3690ed30>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1dd3690eda0>,
#  'delinquents': <gensim.models.keyedvectors.Vocab at 0x1dd3690ecf8>,
#  'rvd': <gensim.models.keyedvectors.Vocab at 0x1dd36b98a90>,
#  'indifference': <gensim.models.keyedvectors.Vocab at 0x1dd36b98ac8>,
#  'reminded': <gensim.models.keyedvectors.Vocab at 0x1dd36ba33c8>,
#  'hangar': <gensim.models.keyedvectors.Vocab at 0x1dd36a6e4a8>,
#  'revived': <gensim.models.keyedvectors.Vocab at 0x1dd36b98b00>,
#  'snippet': <gensim.models.keyedvectors.Vocab at 0x1dd36883da0>,
#  'acquisition': <gensim.models.keyedvectors.Vocab at 0x1dd36883b00>,
#  'saddening': <gensim.models.keyedvectors.Vocab at 0x1dd369825c0>,
#  'roja': <gensim.models.keyedvectors.Vocab at 0x1dd36883828>,
#  'eliza': <gensim.models.keyedvectors.Vocab at 0x1dd3690efd0>,
#  'luminous': <gensim.models.keyedvectors.Vocab at 0x1dd3690edd8>,
#  'mismatched': <gensim.models.keyedvectors.Vocab at 0x1dd3690e518>,
#  'saucers': <gensim.models.keyedvectors.Vocab at 0x1dd36883c50>,
#  'bendix': <gensim.models.keyedvectors.Vocab at 0x1dd36883ef0>,
#  'va': <gensim.models.keyedvectors.Vocab at 0x1dd36883748>,
#  'malone': <gensim.models.keyedvectors.Vocab at 0x1dd38458f60>,
#  'sponsored': <gensim.models.keyedvectors.Vocab at 0x1dd36ba3a90>,
#  'disrespecting': <gensim.models.keyedvectors.Vocab at 0x1dd3690e2b0>,
#  'americanism': <gensim.models.keyedvectors.Vocab at 0x1dd36b78588>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x1dd36a991d0>,
#  'latent': <gensim.models.keyedvectors.Vocab at 0x1dd36982e80>,
#  'performers': <gensim.models.keyedvectors.Vocab at 0x1dd36883710>,
#  'lightner': <gensim.models.keyedvectors.Vocab at 0x1dd3690ef98>,
#  'lili': <gensim.models.keyedvectors.Vocab at 0x1dd36b98ba8>,
#  'hurts': <gensim.models.keyedvectors.Vocab at 0x1dd36982128>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x1dd368832e8>,
#  'languages': <gensim.models.keyedvectors.Vocab at 0x1dd38483fd0>,
#  'knuckles': <gensim.models.keyedvectors.Vocab at 0x1dd36883320>,
#  'utopia': <gensim.models.keyedvectors.Vocab at 0x1dd3849b7f0>,
#  'indicator': <gensim.models.keyedvectors.Vocab at 0x1dd368833c8>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x1dd3690e2e8>,
#  'boheme': <gensim.models.keyedvectors.Vocab at 0x1dd3690e1d0>,
#  'coral': <gensim.models.keyedvectors.Vocab at 0x1dd36a3c128>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x1dd3690e3c8>,
#  'leveled': <gensim.models.keyedvectors.Vocab at 0x1dd36883c18>,
#  'bogie': <gensim.models.keyedvectors.Vocab at 0x1dd36883550>,
#  'dealt': <gensim.models.keyedvectors.Vocab at 0x1dd368830f0>,
#  'realness': <gensim.models.keyedvectors.Vocab at 0x1dd36b98c50>,
#  'gabe': <gensim.models.keyedvectors.Vocab at 0x1dd36b98c88>,
#  'awesomeness': <gensim.models.keyedvectors.Vocab at 0x1dd3690e320>,
#  'sykes': <gensim.models.keyedvectors.Vocab at 0x1dd36883a58>,
#  'depleted': <gensim.models.keyedvectors.Vocab at 0x1dd36afa3c8>,
#  'loco': <gensim.models.keyedvectors.Vocab at 0x1dd3690e400>,
#  'subplot': <gensim.models.keyedvectors.Vocab at 0x1dd3690e358>,
#  'rep': <gensim.models.keyedvectors.Vocab at 0x1dd36883080>,
#  'satisfy': <gensim.models.keyedvectors.Vocab at 0x1dd36a99240>,
#  'orcs': <gensim.models.keyedvectors.Vocab at 0x1dd36b98cc0>,
#  'reverse': <gensim.models.keyedvectors.Vocab at 0x1dd3690e438>,
#  'punctuated': <gensim.models.keyedvectors.Vocab at 0x1dd3690e390>,
#  'afoul': <gensim.models.keyedvectors.Vocab at 0x1dd368834a8>,
#  'hubba': <gensim.models.keyedvectors.Vocab at 0x1dd36a99278>,
#  'dazzled': <gensim.models.keyedvectors.Vocab at 0x1dd36b98d30>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x1dd36a992b0>,
#  'scandinavia': <gensim.models.keyedvectors.Vocab at 0x1dd36a992e8>,
#  'umbrella': <gensim.models.keyedvectors.Vocab at 0x1dd368834e0>,
#  'cuisine': <gensim.models.keyedvectors.Vocab at 0x1dd36883518>,
#  'rothrock': <gensim.models.keyedvectors.Vocab at 0x1dd3690e5f8>,
#  'marine': <gensim.models.keyedvectors.Vocab at 0x1dd3690e470>,
#  'creating': <gensim.models.keyedvectors.Vocab at 0x1dd36883cc0>,
#  'noone': <gensim.models.keyedvectors.Vocab at 0x1dd368835c0>,
#  'lacks': <gensim.models.keyedvectors.Vocab at 0x1dd3690e5c0>,
#  'pistols': <gensim.models.keyedvectors.Vocab at 0x1dd36b98d68>,
#  'hatchet': <gensim.models.keyedvectors.Vocab at 0x1dd3844ae48>,
#  'mullan': <gensim.models.keyedvectors.Vocab at 0x1dd384d7dd8>,
#  'tortoise': <gensim.models.keyedvectors.Vocab at 0x1dd36c8fac8>,
#  'seduces': <gensim.models.keyedvectors.Vocab at 0x1dd36c8a6a0>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x1dd3690e630>,
#  'meadow': <gensim.models.keyedvectors.Vocab at 0x1dd36b414e0>,
#  'diy': <gensim.models.keyedvectors.Vocab at 0x1dd36a99390>,
#  'aesthetic': <gensim.models.keyedvectors.Vocab at 0x1dd36a993c8>,
#  'animatronic': <gensim.models.keyedvectors.Vocab at 0x1dd36b98dd8>,
#  'diminished': <gensim.models.keyedvectors.Vocab at 0x1dd368830b8>,
#  'discouraging': <gensim.models.keyedvectors.Vocab at 0x1dd3699d5c0>,
#  'cigarettes': <gensim.models.keyedvectors.Vocab at 0x1dd38458f98>,
#  'dissection': <gensim.models.keyedvectors.Vocab at 0x1dd36b98e10>,
#  'harbor': <gensim.models.keyedvectors.Vocab at 0x1dd36b98e48>,
#  'scottish': <gensim.models.keyedvectors.Vocab at 0x1dd36ba5f98>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x1dd36bf7518>,
#  'lem': <gensim.models.keyedvectors.Vocab at 0x1dd3699d7f0>,
#  'repressed': <gensim.models.keyedvectors.Vocab at 0x1dd36bc69e8>,
#  'jude': <gensim.models.keyedvectors.Vocab at 0x1dd36a99438>,
#  'frost': <gensim.models.keyedvectors.Vocab at 0x1dd36ca9518>,
#  'truce': <gensim.models.keyedvectors.Vocab at 0x1dd36b98e80>,
#  'slay': <gensim.models.keyedvectors.Vocab at 0x1dd36883630>,
#  'barnaby': <gensim.models.keyedvectors.Vocab at 0x1dd3699da58>,
#  'refusing': <gensim.models.keyedvectors.Vocab at 0x1dd36b98ef0>,
#  'mastery': <gensim.models.keyedvectors.Vocab at 0x1dd36ba8240>,
#  'armando': <gensim.models.keyedvectors.Vocab at 0x1dd36a99470>,
#  'quietly': <gensim.models.keyedvectors.Vocab at 0x1dd36b98f28>,
#  'heather': <gensim.models.keyedvectors.Vocab at 0x1dd36b98f60>,
#  'branded': <gensim.models.keyedvectors.Vocab at 0x1dd36a994a8>,
#  'atwill': <gensim.models.keyedvectors.Vocab at 0x1dd36c77080>,
#  'stump': <gensim.models.keyedvectors.Vocab at 0x1dd36b6c470>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x1dd38467390>,
#  'cody': <gensim.models.keyedvectors.Vocab at 0x1dd36912898>,
#  'surfers': <gensim.models.keyedvectors.Vocab at 0x1dd36a96a58>,
#  'hamilton': <gensim.models.keyedvectors.Vocab at 0x1dd36912588>,
#  'unrated': <gensim.models.keyedvectors.Vocab at 0x1dd36b98f98>,
#  'anyones': <gensim.models.keyedvectors.Vocab at 0x1dd369126d8>,
#  'opens': <gensim.models.keyedvectors.Vocab at 0x1dd36a994e0>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x1dd36b39710>,
#  'desolate': <gensim.models.keyedvectors.Vocab at 0x1dd36a83320>,
#  'underlining': <gensim.models.keyedvectors.Vocab at 0x1dd36890908>,
#  'chemical': <gensim.models.keyedvectors.Vocab at 0x1dd36a99518>,
#  'bulworth': <gensim.models.keyedvectors.Vocab at 0x1dd36c770f0>,
#  'poisons': <gensim.models.keyedvectors.Vocab at 0x1dd36c8fba8>,
#  'glaring': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a080>,
#  'howling': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a0b8>,
#  'showcased': <gensim.models.keyedvectors.Vocab at 0x1dd3690ab00>,
#  'mediocrity': <gensim.models.keyedvectors.Vocab at 0x1dd3690ab70>,
#  'gruber': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a0f0>,
#  'dundee': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a128>,
#  'depended': <gensim.models.keyedvectors.Vocab at 0x1dd36c77160>,
#  'penitentiary': <gensim.models.keyedvectors.Vocab at 0x1dd3690aba8>,
#  'dismember': <gensim.models.keyedvectors.Vocab at 0x1dd3690a358>,
#  'rash': <gensim.models.keyedvectors.Vocab at 0x1dd36a99550>,
#  'dispute': <gensim.models.keyedvectors.Vocab at 0x1dd36c77198>,
#  'possesses': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a198>,
#  'erm': <gensim.models.keyedvectors.Vocab at 0x1dd3690a3c8>,
#  'environmentalist': <gensim.models.keyedvectors.Vocab at 0x1dd36b98390>,
#  'cosy': <gensim.models.keyedvectors.Vocab at 0x1dd36c77208>,
#  'halfway': <gensim.models.keyedvectors.Vocab at 0x1dd36a99588>,
#  'insanity': <gensim.models.keyedvectors.Vocab at 0x1dd36a995c0>,
#  'excised': <gensim.models.keyedvectors.Vocab at 0x1dd36c77240>,
#  'commit': <gensim.models.keyedvectors.Vocab at 0x1dd36ba8e48>,
#  'nearer': <gensim.models.keyedvectors.Vocab at 0x1dd3690ab38>,
#  'fences': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a208>,
#  'publishing': <gensim.models.keyedvectors.Vocab at 0x1dd36a995f8>,
#  'coyote': <gensim.models.keyedvectors.Vocab at 0x1dd36ba8fd0>,
#  'fireflies': <gensim.models.keyedvectors.Vocab at 0x1dd36a99630>,
#  'hiring': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a240>,
#  'documentaries': <gensim.models.keyedvectors.Vocab at 0x1dd36c77320>,
#  'holland': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a278>,
#  'shrewd': <gensim.models.keyedvectors.Vocab at 0x1dd36c23860>,
#  'pigeon': <gensim.models.keyedvectors.Vocab at 0x1dd36bab0f0>,
#  'pervading': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a2b0>,
#  'goke': <gensim.models.keyedvectors.Vocab at 0x1dd3690a4e0>,
#  'leeway': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a2e8>,
#  'lombardi': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a320>,
#  'skyline': <gensim.models.keyedvectors.Vocab at 0x1dd36c84b38>,
#  'german': <gensim.models.keyedvectors.Vocab at 0x1dd3690a400>,
#  'plunged': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a358>,
#  'composed': <gensim.models.keyedvectors.Vocab at 0x1dd36890978>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x1dd36c77358>,
#  'gambit': <gensim.models.keyedvectors.Vocab at 0x1dd36c9d4a8>,
#  'zeta': <gensim.models.keyedvectors.Vocab at 0x1dd369a0cc0>,
#  'typing': <gensim.models.keyedvectors.Vocab at 0x1dd36c77390>,
#  'utilize': <gensim.models.keyedvectors.Vocab at 0x1dd36b1ec18>,
#  'grannies': <gensim.models.keyedvectors.Vocab at 0x1dd3690ae80>,
#  'armstrong': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a3c8>,
#  'lapses': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a400>,
#  'shenanigans': <gensim.models.keyedvectors.Vocab at 0x1dd3690ac18>,
#  'inquiry': <gensim.models.keyedvectors.Vocab at 0x1dd369a0e80>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x1dd36a686d8>,
#  'skeletor': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a438>,
#  'surgeon': <gensim.models.keyedvectors.Vocab at 0x1dd36c77400>,
#  'dion': <gensim.models.keyedvectors.Vocab at 0x1dd369e0fd0>,
#  'pertaining': <gensim.models.keyedvectors.Vocab at 0x1dd36a99710>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a470>,
#  'celluloid': <gensim.models.keyedvectors.Vocab at 0x1dd36a3c1d0>,
#  'moira': <gensim.models.keyedvectors.Vocab at 0x1dd36c77438>,
#  'justifiable': <gensim.models.keyedvectors.Vocab at 0x1dd36a99748>,
#  'dramatize': <gensim.models.keyedvectors.Vocab at 0x1dd3690ae48>,
#  'resnais': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a4a8>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x1dd3690af28>,
#  'paw': <gensim.models.keyedvectors.Vocab at 0x1dd369a10f0>,
#  'dana': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a518>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x1dd36a99780>,
#  'exhaustion': <gensim.models.keyedvectors.Vocab at 0x1dd3690aef0>,
#  'marries': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a550>,
#  'xtro': <gensim.models.keyedvectors.Vocab at 0x1dd36916f28>,
#  'nico': <gensim.models.keyedvectors.Vocab at 0x1dd36b98470>,
#  'lindon': <gensim.models.keyedvectors.Vocab at 0x1dd369e0a90>,
#  'skydiving': <gensim.models.keyedvectors.Vocab at 0x1dd3690afd0>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x1dd36c774e0>,
#  'sebastian': <gensim.models.keyedvectors.Vocab at 0x1dd36c77518>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x1dd36a997f0>,
#  'wo': <gensim.models.keyedvectors.Vocab at 0x1dd36c77550>,
#  'mighty': <gensim.models.keyedvectors.Vocab at 0x1dd36a99828>,
#  'hysterically': <gensim.models.keyedvectors.Vocab at 0x1dd36c77588>,
#  'tat': <gensim.models.keyedvectors.Vocab at 0x1dd36c775c0>,
#  'mulholland': <gensim.models.keyedvectors.Vocab at 0x1dd3690af98>,
#  'portfolio': <gensim.models.keyedvectors.Vocab at 0x1dd36890518>,
#  'cusp': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a588>,
#  'spouts': <gensim.models.keyedvectors.Vocab at 0x1dd36a99898>,
#  'tamil': <gensim.models.keyedvectors.Vocab at 0x1dd3690af60>,
#  'cannes': <gensim.models.keyedvectors.Vocab at 0x1dd36c775f8>,
#  'cinematics': <gensim.models.keyedvectors.Vocab at 0x1dd36c77630>,
#  'flame': <gensim.models.keyedvectors.Vocab at 0x1dd36a998d0>,
#  'gruff': <gensim.models.keyedvectors.Vocab at 0x1dd36bad1d0>,
#  'eastman': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a5c0>,
#  'shrill': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a5f8>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x1dd36ab40b8>,
#  'bloom': <gensim.models.keyedvectors.Vocab at 0x1dd36c776d8>,
#  'rating': <gensim.models.keyedvectors.Vocab at 0x1dd36bad4a8>,
#  'elias': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a630>,
#  'relations': <gensim.models.keyedvectors.Vocab at 0x1dd36a99908>,
#  'aware': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a668>,
#  'otis': <gensim.models.keyedvectors.Vocab at 0x1dd369a1c88>,
#  'jaane': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a6a0>,
#  'escapades': <gensim.models.keyedvectors.Vocab at 0x1dd36a99940>,
#  'guerrero': <gensim.models.keyedvectors.Vocab at 0x1dd3690a4a8>,
#  'spinning': <gensim.models.keyedvectors.Vocab at 0x1dd36a99978>,
#  'sakina': <gensim.models.keyedvectors.Vocab at 0x1dd36bad860>,
#  'blast': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a6d8>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x1dd36c90470>,
#  'converting': <gensim.models.keyedvectors.Vocab at 0x1dd36c77748>,
#  'caviezel': <gensim.models.keyedvectors.Vocab at 0x1dd3690a198>,
#  'heroic': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a710>,
#  'journeys': <gensim.models.keyedvectors.Vocab at 0x1dd36a999b0>,
#  'bayou': <gensim.models.keyedvectors.Vocab at 0x1dd36c77780>,
#  'hammer': <gensim.models.keyedvectors.Vocab at 0x1dd36b7f9b0>,
#  'quits': <gensim.models.keyedvectors.Vocab at 0x1dd36a999e8>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x1dd38493be0>,
#  'flows': <gensim.models.keyedvectors.Vocab at 0x1dd36badcf8>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x1dd36a99a20>,
#  'nile': <gensim.models.keyedvectors.Vocab at 0x1dd36a99a58>,
#  'spells': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a748>,
#  'stomps': <gensim.models.keyedvectors.Vocab at 0x1dd36a99a90>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x1dd3690a0f0>,
#  'stifle': <gensim.models.keyedvectors.Vocab at 0x1dd36a99b00>,
#  'saddam': <gensim.models.keyedvectors.Vocab at 0x1dd3690a1d0>,
#  'spielberg': <gensim.models.keyedvectors.Vocab at 0x1dd3690a240>,
#  'malick': <gensim.models.keyedvectors.Vocab at 0x1dd36c77860>,
#  'phallic': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a780>,
#  'fabrication': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a7b8>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a7f0>,
#  'ravages': <gensim.models.keyedvectors.Vocab at 0x1dd36bb1198>,
#  'paranoia': <gensim.models.keyedvectors.Vocab at 0x1dd3690a908>,
#  'cynthia': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a860>,
#  'underestimated': <gensim.models.keyedvectors.Vocab at 0x1dd3690a2e8>,
#  'cuddly': <gensim.models.keyedvectors.Vocab at 0x1dd36ca96d8>,
#  'interpretations': <gensim.models.keyedvectors.Vocab at 0x1dd3690a2b0>,
#  'condom': <gensim.models.keyedvectors.Vocab at 0x1dd36a99b70>,
#  'glover': <gensim.models.keyedvectors.Vocab at 0x1dd368aa828>,
#  'serbia': <gensim.models.keyedvectors.Vocab at 0x1dd3690a390>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x1dd3690a518>,
#  'mongol': <gensim.models.keyedvectors.Vocab at 0x1dd36a3c278>,
#  'playmate': <gensim.models.keyedvectors.Vocab at 0x1dd36b6c630>,
#  'oddest': <gensim.models.keyedvectors.Vocab at 0x1dd36c77908>,
#  'concorde': <gensim.models.keyedvectors.Vocab at 0x1dd3690a5c0>,
#  'wilds': <gensim.models.keyedvectors.Vocab at 0x1dd3690a630>,
#  'hobo': <gensim.models.keyedvectors.Vocab at 0x1dd36b006a0>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x1dd38496208>,
#  'guitarist': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a8d0>,
#  'gals': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a908>,
#  'mish': <gensim.models.keyedvectors.Vocab at 0x1dd36c96898>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x1dd36a99ba8>,
#  'valli': <gensim.models.keyedvectors.Vocab at 0x1dd36b9a978>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x1dd3690a6d8>,
#  'incomprehensibly': <gensim.models.keyedvectors.Vocab at 0x1dd36c779b0>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x1dd3690a748>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x1dd36a1e518>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x1dd36c77a20>,
#  'recommendations': <gensim.models.keyedvectors.Vocab at 0x1dd36c77a58>,
#  'underway': <gensim.models.keyedvectors.Vocab at 0x1dd3690a7b8>,
#  'troupe': <gensim.models.keyedvectors.Vocab at 0x1dd3690a7f0>,
#  'misfortunes': <gensim.models.keyedvectors.Vocab at 0x1dd3690a860>,
#  'peppard': <gensim.models.keyedvectors.Vocab at 0x1dd3690a780>,
#  'rotor': <gensim.models.keyedvectors.Vocab at 0x1dd36c77ac8>,
#  'introduce': <gensim.models.keyedvectors.Vocab at 0x1dd3690a828>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x1dd36c77b00>,
#  'woland': <gensim.models.keyedvectors.Vocab at 0x1dd36b9aa58>,
#  'wheel': <gensim.models.keyedvectors.Vocab at 0x1dd3690a710>,
#  'identities': <gensim.models.keyedvectors.Vocab at 0x1dd3690a8d0>,
#  'redeemable': <gensim.models.keyedvectors.Vocab at 0x1dd36a99c50>,
#  'ww': <gensim.models.keyedvectors.Vocab at 0x1dd3690a898>,
#  'enmeshed': <gensim.models.keyedvectors.Vocab at 0x1dd3690a550>,
#  'ripper': <gensim.models.keyedvectors.Vocab at 0x1dd369a48d0>,
#  'vargas': <gensim.models.keyedvectors.Vocab at 0x1dd36b9aac8>,
#  'aerial': <gensim.models.keyedvectors.Vocab at 0x1dd36a99c88>,
#  'ames': <gensim.models.keyedvectors.Vocab at 0x1dd36a96ba8>,
#  'jackhammer': <gensim.models.keyedvectors.Vocab at 0x1dd36a99cc0>,
#  'channing': <gensim.models.keyedvectors.Vocab at 0x1dd36c77b70>,
#  'tuition': <gensim.models.keyedvectors.Vocab at 0x1dd3690a5f8>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x1dd36c77ba8>,
#  'tattooed': <gensim.models.keyedvectors.Vocab at 0x1dd3690a320>,
#  'filone': <gensim.models.keyedvectors.Vocab at 0x1dd36a99cf8>,
#  'sven': <gensim.models.keyedvectors.Vocab at 0x1dd36a99d30>,
#  'behaviour': <gensim.models.keyedvectors.Vocab at 0x1dd36c77be0>,
#  'massage': <gensim.models.keyedvectors.Vocab at 0x1dd3690a128>,
#  'impressively': <gensim.models.keyedvectors.Vocab at 0x1dd36a94588>,
#  'uma': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ab70>,
#  'puzzlement': <gensim.models.keyedvectors.Vocab at 0x1dd36a99d68>,
#  'parachutes': <gensim.models.keyedvectors.Vocab at 0x1dd36c77c18>,
#  'freebie': <gensim.models.keyedvectors.Vocab at 0x1dd36c987b8>,
#  'infrastructure': <gensim.models.keyedvectors.Vocab at 0x1dd3690a208>,
#  'yen': <gensim.models.keyedvectors.Vocab at 0x1dd36b9aba8>,
#  'olympus': <gensim.models.keyedvectors.Vocab at 0x1dd36a99da0>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x1dd3690a160>,
#  'sondra': <gensim.models.keyedvectors.Vocab at 0x1dd36a99e10>,
#  'kathy': <gensim.models.keyedvectors.Vocab at 0x1dd3690a978>,
#  'emerson': <gensim.models.keyedvectors.Vocab at 0x1dd3690ac50>,
#  'maids': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ac50>,
#  'bolivia': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ac88>,
#  'carlyle': <gensim.models.keyedvectors.Vocab at 0x1dd38443048>,
#  'spelling': <gensim.models.keyedvectors.Vocab at 0x1dd3690ac88>,
#  'appallingly': <gensim.models.keyedvectors.Vocab at 0x1dd36bb39b0>,
#  'aha': <gensim.models.keyedvectors.Vocab at 0x1dd36b9acc0>,
#  'valid': <gensim.models.keyedvectors.Vocab at 0x1dd3690ad68>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x1dd36c77c88>,
#  'tormentors': <gensim.models.keyedvectors.Vocab at 0x1dd36bf7748>,
#  'madly': <gensim.models.keyedvectors.Vocab at 0x1dd3690acc0>,
#  'mercer': <gensim.models.keyedvectors.Vocab at 0x1dd3690add8>,
#  'moldy': <gensim.models.keyedvectors.Vocab at 0x1dd36c77cc0>,
#  'processed': <gensim.models.keyedvectors.Vocab at 0x1dd384862e8>,
#  'dice': <gensim.models.keyedvectors.Vocab at 0x1dd36a99ef0>,
#  'mantegna': <gensim.models.keyedvectors.Vocab at 0x1dd3690ad30>,
#  'saddles': <gensim.models.keyedvectors.Vocab at 0x1dd36c77cf8>,
#  'felons': <gensim.models.keyedvectors.Vocab at 0x1dd36c8d5f8>,
#  'levinson': <gensim.models.keyedvectors.Vocab at 0x1dd36a99f28>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x1dd36a99f60>,
#  'carney': <gensim.models.keyedvectors.Vocab at 0x1dd3690ada0>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ad68>,
#  'abusive': <gensim.models.keyedvectors.Vocab at 0x1dd36c8fda0>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x1dd36c8d550>,
#  'piano': <gensim.models.keyedvectors.Vocab at 0x1dd36b6c748>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ada0>,
#  'executing': <gensim.models.keyedvectors.Vocab at 0x1dd3690ae10>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x1dd36c77d68>,
#  'powered': <gensim.models.keyedvectors.Vocab at 0x1dd36c77da0>,
#  'der': <gensim.models.keyedvectors.Vocab at 0x1dd36a99fd0>,
#  'pill': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b048>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b080>,
#  'kingdoms': <gensim.models.keyedvectors.Vocab at 0x1dd36c77e10>,
#  'thud': <gensim.models.keyedvectors.Vocab at 0x1dd36b9add8>,
#  'financially': <gensim.models.keyedvectors.Vocab at 0x1dd36bb6550>,
#  'contracts': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ae10>,
#  'dumpster': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b0b8>,
#  'nastier': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ae48>,
#  'thailand': <gensim.models.keyedvectors.Vocab at 0x1dd368d2748>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b0f0>,
#  'accomplish': <gensim.models.keyedvectors.Vocab at 0x1dd368d2da0>,
#  'percentage': <gensim.models.keyedvectors.Vocab at 0x1dd36c77e80>,
#  'willy': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b128>,
#  'ow': <gensim.models.keyedvectors.Vocab at 0x1dd36c77ef0>,
#  'ambushers': <gensim.models.keyedvectors.Vocab at 0x1dd36bb66d8>,
#  'peerless': <gensim.models.keyedvectors.Vocab at 0x1dd36b23e80>,
#  'cem': <gensim.models.keyedvectors.Vocab at 0x1dd368d2048>,
#  'jilted': <gensim.models.keyedvectors.Vocab at 0x1dd36bb6780>,
#  'invests': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b160>,
#  'skipping': <gensim.models.keyedvectors.Vocab at 0x1dd36a197f0>,
#  'excessive': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b198>,
#  'foreseen': <gensim.models.keyedvectors.Vocab at 0x1dd369a7828>,
#  'evans': <gensim.models.keyedvectors.Vocab at 0x1dd368d2b70>,
#  'invariably': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b1d0>,
#  'headaches': <gensim.models.keyedvectors.Vocab at 0x1dd36b850b8>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x1dd36c77f28>,
#  'romp': <gensim.models.keyedvectors.Vocab at 0x1dd36b9aef0>,
#  'daggers': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b208>,
#  'spoilt': <gensim.models.keyedvectors.Vocab at 0x1dd368d22b0>,
#  'lindfors': <gensim.models.keyedvectors.Vocab at 0x1dd368d2b00>,
#  'burrows': <gensim.models.keyedvectors.Vocab at 0x1dd36b9af28>,
#  'dismayed': <gensim.models.keyedvectors.Vocab at 0x1dd36c77f98>,
#  'admit': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b240>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x1dd36b9af60>,
#  'disadvantage': <gensim.models.keyedvectors.Vocab at 0x1dd368d2c18>,
#  'carter': <gensim.models.keyedvectors.Vocab at 0x1dd36c77fd0>,
#  'talman': <gensim.models.keyedvectors.Vocab at 0x1dd369a7c88>,
#  'dunst': <gensim.models.keyedvectors.Vocab at 0x1dd369a7be0>,
#  'vaughan': <gensim.models.keyedvectors.Vocab at 0x1dd36c79080>,
#  'scratching': <gensim.models.keyedvectors.Vocab at 0x1dd3845a278>,
#  'bunker': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b278>,
#  'animes': <gensim.models.keyedvectors.Vocab at 0x1dd36c790b8>,
#  'broadway': <gensim.models.keyedvectors.Vocab at 0x1dd36bb6f98>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x1dd38486400>,
#  'brick': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b2b0>,
#  'sorbo': <gensim.models.keyedvectors.Vocab at 0x1dd369a90b8>,
#  'jacket': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b2e8>,
#  'santini': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e048>,
#  'mortuary': <gensim.models.keyedvectors.Vocab at 0x1dd369a90f0>,
#  'yikes': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b320>,
#  'sevier': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b358>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e0f0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1dd36c8fe10>,
#  'henri': <gensim.models.keyedvectors.Vocab at 0x1dd368d2898>,
#  'shooter': <gensim.models.keyedvectors.Vocab at 0x1dd36890470>,
#  'jaclyn': <gensim.models.keyedvectors.Vocab at 0x1dd36c79160>,
#  'kwai': <gensim.models.keyedvectors.Vocab at 0x1dd36b98710>,
#  'loop': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e160>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b390>,
#  'tasting': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b3c8>,
#  'smackdown': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b400>,
#  'advert': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b438>,
#  'unfriendly': <gensim.models.keyedvectors.Vocab at 0x1dd36c791d0>,
#  'tends': <gensim.models.keyedvectors.Vocab at 0x1dd368d29b0>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e208>,
#  'enslaved': <gensim.models.keyedvectors.Vocab at 0x1dd368d2978>,
#  'triumph': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b470>,
#  'donne': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e240>,
#  'owners': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e278>,
#  'proust': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e2b0>,
#  'authentically': <gensim.models.keyedvectors.Vocab at 0x1dd368d2a58>,
#  'baths': <gensim.models.keyedvectors.Vocab at 0x1dd38475390>,
#  'paces': <gensim.models.keyedvectors.Vocab at 0x1dd368d2dd8>,
#  'suzy': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e2e8>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b4e0>,
#  'liquor': <gensim.models.keyedvectors.Vocab at 0x1dd36bb8d30>,
#  'tangible': <gensim.models.keyedvectors.Vocab at 0x1dd3690e0b8>,
#  'mickie': <gensim.models.keyedvectors.Vocab at 0x1dd368d2080>,
#  'creepy': <gensim.models.keyedvectors.Vocab at 0x1dd368d2198>,
#  'belafonte': <gensim.models.keyedvectors.Vocab at 0x1dd368d2828>,
#  'psychlos': <gensim.models.keyedvectors.Vocab at 0x1dd368d2cc0>,
#  'wheeling': <gensim.models.keyedvectors.Vocab at 0x1dd368d2390>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x1dd368d2208>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x1dd36c79278>,
#  'excluded': <gensim.models.keyedvectors.Vocab at 0x1dd368d2780>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x1dd36c792b0>,
#  'attends': <gensim.models.keyedvectors.Vocab at 0x1dd36890208>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b518>,
#  'abort': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e3c8>,
#  'caper': <gensim.models.keyedvectors.Vocab at 0x1dd36bbb1d0>,
#  'loyalty': <gensim.models.keyedvectors.Vocab at 0x1dd3845a358>,
#  'vilma': <gensim.models.keyedvectors.Vocab at 0x1dd384a4320>,
#  'haig': <gensim.models.keyedvectors.Vocab at 0x1dd36c792e8>,
#  'holding': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b550>,
#  'stampede': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b588>,
#  'pastiches': <gensim.models.keyedvectors.Vocab at 0x1dd36c79320>,
#  'andersson': <gensim.models.keyedvectors.Vocab at 0x1dd368d2160>,
#  'aaja': <gensim.models.keyedvectors.Vocab at 0x1dd368d2c88>,
#  'jayne': <gensim.models.keyedvectors.Vocab at 0x1dd36bbb400>,
#  'rainbow': <gensim.models.keyedvectors.Vocab at 0x1dd368ced68>,
#  'retro': <gensim.models.keyedvectors.Vocab at 0x1dd36bbb4e0>,
#  'yuzna': <gensim.models.keyedvectors.Vocab at 0x1dd36c79358>,
#  'goddess': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b5c0>,
#  'hutton': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e438>,
#  'nifty': <gensim.models.keyedvectors.Vocab at 0x1dd368902e8>,
#  'recruiting': <gensim.models.keyedvectors.Vocab at 0x1dd368cecf8>,
#  'controlling': <gensim.models.keyedvectors.Vocab at 0x1dd36c79390>,
#  'syrup': <gensim.models.keyedvectors.Vocab at 0x1dd368ce4e0>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x1dd36bbb828>,
#  'portland': <gensim.models.keyedvectors.Vocab at 0x1dd36c77828>,
#  'untalented': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e470>,
#  'bettany': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e4a8>,
#  'fingernails': <gensim.models.keyedvectors.Vocab at 0x1dd36c4ed30>,
#  'exceptionally': <gensim.models.keyedvectors.Vocab at 0x1dd36c793c8>,
#  'wacky': <gensim.models.keyedvectors.Vocab at 0x1dd368ce6d8>,
#  'overdone': <gensim.models.keyedvectors.Vocab at 0x1dd36bbbb38>,
#  'rowling': <gensim.models.keyedvectors.Vocab at 0x1dd368cef60>,
#  'rips': <gensim.models.keyedvectors.Vocab at 0x1dd38486470>,
#  'warrior': <gensim.models.keyedvectors.Vocab at 0x1dd368ced30>,
#  'humorless': <gensim.models.keyedvectors.Vocab at 0x1dd3848d400>,
#  'normality': <gensim.models.keyedvectors.Vocab at 0x1dd36c79438>,
#  'intolerant': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b5f8>,
#  'identification': <gensim.models.keyedvectors.Vocab at 0x1dd384c1550>,
#  'chaps': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b630>,
#  'nin': <gensim.models.keyedvectors.Vocab at 0x1dd36bbbeb8>,
#  'dutch': <gensim.models.keyedvectors.Vocab at 0x1dd36c794a8>,
#  'drummer': <gensim.models.keyedvectors.Vocab at 0x1dd38493dd8>,
#  'ti': <gensim.models.keyedvectors.Vocab at 0x1dd384b1978>,
#  'fardeen': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b668>,
#  'befriending': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b6a0>,
#  'kashmir': <gensim.models.keyedvectors.Vocab at 0x1dd384c1978>,
#  'jungles': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b6d8>,
#  'buckman': <gensim.models.keyedvectors.Vocab at 0x1dd36c794e0>,
#  'croatia': <gensim.models.keyedvectors.Vocab at 0x1dd368ce550>,
#  'fuzz': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b748>,
#  'gag': <gensim.models.keyedvectors.Vocab at 0x1dd36ac1588>,
#  'viewings': <gensim.models.keyedvectors.Vocab at 0x1dd368ce4a8>,
#  'accountable': <gensim.models.keyedvectors.Vocab at 0x1dd36a94f28>,
#  'subscribe': <gensim.models.keyedvectors.Vocab at 0x1dd368ce470>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x1dd36a3c4a8>,
#  'entendre': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e5c0>,
#  'wanna': <gensim.models.keyedvectors.Vocab at 0x1dd368ce668>,
#  'theorists': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e5f8>,
#  'unintentionally': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b7f0>,
#  'giggled': <gensim.models.keyedvectors.Vocab at 0x1dd368ce588>,
#  'unheard': <gensim.models.keyedvectors.Vocab at 0x1dd36c79518>,
#  'separately': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b828>,
#  'resolving': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b860>,
#  'charisma': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e630>,
#  'tame': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e668>,
#  'clemons': <gensim.models.keyedvectors.Vocab at 0x1dd36c79550>,
#  'mustang': <gensim.models.keyedvectors.Vocab at 0x1dd36a68dd8>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x1dd36c79588>,
#  'songs': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e6d8>,
#  'thinner': <gensim.models.keyedvectors.Vocab at 0x1dd368ce630>,
#  'rattle': <gensim.models.keyedvectors.Vocab at 0x1dd3845a400>,
#  'chills': <gensim.models.keyedvectors.Vocab at 0x1dd36c795c0>,
#  'servants': <gensim.models.keyedvectors.Vocab at 0x1dd368ce908>,
#  'supermarket': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e748>,
#  'boomer': <gensim.models.keyedvectors.Vocab at 0x1dd36bbe7b8>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b908>,
#  'inspires': <gensim.models.keyedvectors.Vocab at 0x1dd36a4f240>,
#  'demise': <gensim.models.keyedvectors.Vocab at 0x1dd36a6e2b0>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x1dd36b15c50>,
#  'rts': <gensim.models.keyedvectors.Vocab at 0x1dd36c79630>,
#  'ballistic': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e7b8>,
#  'moot': <gensim.models.keyedvectors.Vocab at 0x1dd368ceac8>,
#  'empress': <gensim.models.keyedvectors.Vocab at 0x1dd369ab128>,
#  'orientated': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b940>,
#  'geez': <gensim.models.keyedvectors.Vocab at 0x1dd36bbeba8>,
#  'showering': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e7f0>,
#  'filmographies': <gensim.models.keyedvectors.Vocab at 0x1dd36bbebe0>,
#  'mu': <gensim.models.keyedvectors.Vocab at 0x1dd368ce748>,
#  'fashions': <gensim.models.keyedvectors.Vocab at 0x1dd368ce390>,
#  'immobile': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b978>,
#  'forster': <gensim.models.keyedvectors.Vocab at 0x1dd368ce080>,
#  'munch': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b9b0>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x1dd368ce6a0>,
#  'embarked': <gensim.models.keyedvectors.Vocab at 0x1dd368cecc0>,
#  'gar': <gensim.models.keyedvectors.Vocab at 0x1dd36a9b9e8>,
#  'copper': <gensim.models.keyedvectors.Vocab at 0x1dd384b1a20>,
#  'earthly': <gensim.models.keyedvectors.Vocab at 0x1dd368ceeb8>,
#  'winds': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ba20>,
#  'duguay': <gensim.models.keyedvectors.Vocab at 0x1dd36c79748>,
#  'peralta': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ba58>,
#  'sketch': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ba90>,
#  'johnnie': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e908>,
#  'embezzled': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bac8>,
#  'scholars': <gensim.models.keyedvectors.Vocab at 0x1dd36b98898>,
#  'correspond': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e940>,
#  'hairstyles': <gensim.models.keyedvectors.Vocab at 0x1dd36b9e9b0>,
#  'cusak': <gensim.models.keyedvectors.Vocab at 0x1dd368ceb70>,
#  'satirize': <gensim.models.keyedvectors.Vocab at 0x1dd36b15cc0>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x1dd36c797f0>,
#  'gremlin': <gensim.models.keyedvectors.Vocab at 0x1dd369362b0>,
#  'envisioned': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ea20>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x1dd36890080>,
#  'bruce': <gensim.models.keyedvectors.Vocab at 0x1dd36c8ff60>,
#  'heartless': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ea58>,
#  'knockout': <gensim.models.keyedvectors.Vocab at 0x1dd3849b908>,
#  'sidelines': <gensim.models.keyedvectors.Vocab at 0x1dd36b9eac8>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x1dd36936358>,
#  'independently': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bb00>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bb38>,
#  'flapping': <gensim.models.keyedvectors.Vocab at 0x1dd369b0940>,
#  'afghan': <gensim.models.keyedvectors.Vocab at 0x1dd36bc0a20>,
#  'alumni': <gensim.models.keyedvectors.Vocab at 0x1dd36936668>,
#  'klux': <gensim.models.keyedvectors.Vocab at 0x1dd36c79898>,
#  'untrue': <gensim.models.keyedvectors.Vocab at 0x1dd36b9eb38>,
#  'bizarrely': <gensim.models.keyedvectors.Vocab at 0x1dd369367f0>,
#  'whaley': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bbe0>,
#  'spotting': <gensim.models.keyedvectors.Vocab at 0x1dd36bc0be0>,
#  'troll': <gensim.models.keyedvectors.Vocab at 0x1dd36c79940>,
#  'ringer': <gensim.models.keyedvectors.Vocab at 0x1dd36ae20f0>,
#  'amateurs': <gensim.models.keyedvectors.Vocab at 0x1dd36b9eba8>,
#  'wongo': <gensim.models.keyedvectors.Vocab at 0x1dd36c23be0>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bc50>,
#  'tearjerker': <gensim.models.keyedvectors.Vocab at 0x1dd36bc6d68>,
#  'brolin': <gensim.models.keyedvectors.Vocab at 0x1dd369364e0>,
#  'ming': <gensim.models.keyedvectors.Vocab at 0x1dd36bc0eb8>,
#  'cecil': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ebe0>,
#  'copland': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bcc0>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x1dd36a60978>,
#  'ja': <gensim.models.keyedvectors.Vocab at 0x1dd36936978>,
#  'noonan': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ec18>,
#  'nest': <gensim.models.keyedvectors.Vocab at 0x1dd36c8ffd0>,
#  'onj': <gensim.models.keyedvectors.Vocab at 0x1dd36af8400>,
#  'laborious': <gensim.models.keyedvectors.Vocab at 0x1dd369b5a20>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1dd36936630>,
#  'overthrow': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ec88>,
#  'overbearing': <gensim.models.keyedvectors.Vocab at 0x1dd36936518>,
#  'critic': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bcf8>,
#  'antics': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bd30>,
#  'daniels': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ed30>,
#  'duchess': <gensim.models.keyedvectors.Vocab at 0x1dd36cae0b8>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x1dd369365c0>,
#  'rigs': <gensim.models.keyedvectors.Vocab at 0x1dd3849eda0>,
#  'poked': <gensim.models.keyedvectors.Vocab at 0x1dd36c98f60>,
#  'mm': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bd68>,
#  'pointedly': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ed68>,
#  'cauldron': <gensim.models.keyedvectors.Vocab at 0x1dd36936550>,
#  'exudes': <gensim.models.keyedvectors.Vocab at 0x1dd36c799e8>,
#  'supported': <gensim.models.keyedvectors.Vocab at 0x1dd36936588>,
#  'communities': <gensim.models.keyedvectors.Vocab at 0x1dd36c79a20>,
#  'endeavors': <gensim.models.keyedvectors.Vocab at 0x1dd36c79a58>,
#  'assures': <gensim.models.keyedvectors.Vocab at 0x1dd369366d8>,
#  'reviewed': <gensim.models.keyedvectors.Vocab at 0x1dd369365f8>,
#  'digits': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bdd8>,
#  'trusted': <gensim.models.keyedvectors.Vocab at 0x1dd36b9eda0>,
#  'utilises': <gensim.models.keyedvectors.Vocab at 0x1dd36bc49b0>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x1dd36c79a90>,
# ...
#  'carrie': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bef0>,
#  'indecipherable': <gensim.models.keyedvectors.Vocab at 0x1dd36a3c5f8>,
#  'chant': <gensim.models.keyedvectors.Vocab at 0x1dd36c79b70>,
#  'asteroid': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ef60>,
#  'neighborhood': <gensim.models.keyedvectors.Vocab at 0x1dd36b9ef98>,
#  'vendor': <gensim.models.keyedvectors.Vocab at 0x1dd36b9efd0>,
#  'examines': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0048>,
#  'mite': <gensim.models.keyedvectors.Vocab at 0x1dd36ca3908>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0080>,
#  'locals': <gensim.models.keyedvectors.Vocab at 0x1dd36936ba8>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1dd36ba00f0>,
#  'absorption': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bf28>,
#  'normand': <gensim.models.keyedvectors.Vocab at 0x1dd36c79c18>,
#  'annie': <gensim.models.keyedvectors.Vocab at 0x1dd384865c0>,
#  'swerves': <gensim.models.keyedvectors.Vocab at 0x1dd36936a20>,
#  'showings': <gensim.models.keyedvectors.Vocab at 0x1dd36bbb3c8>,
#  'sisko': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0128>,
#  'newbies': <gensim.models.keyedvectors.Vocab at 0x1dd36936b70>,
#  'turbulence': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0160>,
#  'avenging': <gensim.models.keyedvectors.Vocab at 0x1dd36936ac8>,
#  'tornado': <gensim.models.keyedvectors.Vocab at 0x1dd36936b38>,
#  'cosmopolitan': <gensim.models.keyedvectors.Vocab at 0x1dd36936a58>,
#  'wardens': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bf60>,
#  'downgraded': <gensim.models.keyedvectors.Vocab at 0x1dd36c79c88>,
#  'assistants': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0198>,
#  'olsen': <gensim.models.keyedvectors.Vocab at 0x1dd369b54e0>,
#  'muffled': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bf98>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x1dd36a9bfd0>,
#  'hells': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e048>,
#  'kochanski': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0208>,
#  'remaining': <gensim.models.keyedvectors.Vocab at 0x1dd369b5550>,
#  'cuddle': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e080>,
#  'carly': <gensim.models.keyedvectors.Vocab at 0x1dd36936c88>,
#  'fabricated': <gensim.models.keyedvectors.Vocab at 0x1dd36c79d68>,
#  'akhtar': <gensim.models.keyedvectors.Vocab at 0x1dd384b1ac8>,
#  'flips': <gensim.models.keyedvectors.Vocab at 0x1dd36936a90>,
#  'shabby': <gensim.models.keyedvectors.Vocab at 0x1dd36936b00>,
#  'bart': <gensim.models.keyedvectors.Vocab at 0x1dd36ca99e8>,
#  'dussollier': <gensim.models.keyedvectors.Vocab at 0x1dd36ba02b0>,
#  'deciding': <gensim.models.keyedvectors.Vocab at 0x1dd36936748>,
#  'milian': <gensim.models.keyedvectors.Vocab at 0x1dd36c9de48>,
#  'kungfu': <gensim.models.keyedvectors.Vocab at 0x1dd36936c50>,
#  'glenville': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e0b8>,
#  'shortage': <gensim.models.keyedvectors.Vocab at 0x1dd36c79da0>,
#  'knights': <gensim.models.keyedvectors.Vocab at 0x1dd36c79dd8>,
#  'stickler': <gensim.models.keyedvectors.Vocab at 0x1dd36b28c50>,
#  'cease': <gensim.models.keyedvectors.Vocab at 0x1dd36ba02e8>,
#  'jones': <gensim.models.keyedvectors.Vocab at 0x1dd36a94400>,
#  'flopped': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e0f0>,
#  'valentine': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0320>,
#  'prince': <gensim.models.keyedvectors.Vocab at 0x1dd36936828>,
#  'detachment': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0358>,
#  'kull': <gensim.models.keyedvectors.Vocab at 0x1dd36b41978>,
#  'eschews': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0390>,
#  'outpost': <gensim.models.keyedvectors.Vocab at 0x1dd369367b8>,
#  'electra': <gensim.models.keyedvectors.Vocab at 0x1dd369b5f28>,
#  'rerun': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e128>,
#  'soundtracks': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0400>,
#  'insane': <gensim.models.keyedvectors.Vocab at 0x1dd36c79ef0>,
#  'peck': <gensim.models.keyedvectors.Vocab at 0x1dd36bc95f8>,
#  'lovett': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e160>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e198>,
#  'angel': <gensim.models.keyedvectors.Vocab at 0x1dd36bc9710>,
#  'tickles': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0438>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x1dd36c79fd0>,
#  'shuddery': <gensim.models.keyedvectors.Vocab at 0x1dd384a46d8>,
#  'plumage': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0470>,
#  'couldnt': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a080>,
#  'milo': <gensim.models.keyedvectors.Vocab at 0x1dd36ba04a8>,
#  'leeson': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a0b8>,
#  'everytime': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e1d0>,
#  'segments': <gensim.models.keyedvectors.Vocab at 0x1dd36936898>,
#  'carre': <gensim.models.keyedvectors.Vocab at 0x1dd36a09860>,
#  'undercover': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e208>,
#  'motivations': <gensim.models.keyedvectors.Vocab at 0x1dd36936940>,
#  'rot': <gensim.models.keyedvectors.Vocab at 0x1dd36c23e48>,
#  'biology': <gensim.models.keyedvectors.Vocab at 0x1dd369b76d8>,
#  'merrily': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0518>,
#  'scorching': <gensim.models.keyedvectors.Vocab at 0x1dd369b5c88>,
#  'zone': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e278>,
#  'foils': <gensim.models.keyedvectors.Vocab at 0x1dd36936908>,
#  'wednesday': <gensim.models.keyedvectors.Vocab at 0x1dd36936860>,
#  'incomplete': <gensim.models.keyedvectors.Vocab at 0x1dd384b1b38>,
#  'bridge': <gensim.models.keyedvectors.Vocab at 0x1dd369368d0>,
#  'villa': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a128>,
#  'quantity': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e2e8>,
#  'standouts': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0588>,
#  'launching': <gensim.models.keyedvectors.Vocab at 0x1dd369b7ba8>,
#  'fantasia': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e358>,
#  'haneke': <gensim.models.keyedvectors.Vocab at 0x1dd36ba05c0>,
#  'cruise': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a160>,
#  'seagal': <gensim.models.keyedvectors.Vocab at 0x1dd36c90128>,
#  'dances': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a198>,
#  'carved': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0630>,
#  'nationwide': <gensim.models.keyedvectors.Vocab at 0x1dd36936320>,
#  'renee': <gensim.models.keyedvectors.Vocab at 0x1dd369369b0>,
#  'achievements': <gensim.models.keyedvectors.Vocab at 0x1dd36ba06a0>,
#  'goths': <gensim.models.keyedvectors.Vocab at 0x1dd38486668>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1dd36ba06d8>,
#  'louie': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0710>,
#  'ying': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a1d0>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x1dd36bcb710>,
#  'embarrasses': <gensim.models.keyedvectors.Vocab at 0x1dd369369e8>,
#  'taped': <gensim.models.keyedvectors.Vocab at 0x1dd384b1ba8>,
#  'applauding': <gensim.models.keyedvectors.Vocab at 0x1dd369360b8>,
#  'progressive': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e390>,
#  'rehearsing': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e3c8>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0748>,
#  'moan': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0780>,
#  'rely': <gensim.models.keyedvectors.Vocab at 0x1dd36ba07b8>,
#  'danes': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e438>,
#  'peopled': <gensim.models.keyedvectors.Vocab at 0x1dd36ba07f0>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a278>,
#  'pratt': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a2b0>,
#  'ahmet': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a2e8>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x1dd36b9aa20>,
#  'asap': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e470>,
#  'gozu': <gensim.models.keyedvectors.Vocab at 0x1dd36936048>,
#  'pleaser': <gensim.models.keyedvectors.Vocab at 0x1dd36a68fd0>,
#  'suspicions': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0828>,
#  'rainer': <gensim.models.keyedvectors.Vocab at 0x1dd36aed3c8>,
#  'machinations': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a320>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x1dd36936160>,
#  'enhancement': <gensim.models.keyedvectors.Vocab at 0x1dd36936080>,
#  'descending': <gensim.models.keyedvectors.Vocab at 0x1dd36936198>,
#  'hierarchy': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e4a8>,
#  'excerpt': <gensim.models.keyedvectors.Vocab at 0x1dd36ca1d68>,
#  'relocated': <gensim.models.keyedvectors.Vocab at 0x1dd36c23f28>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e4e0>,
#  'mewtwo': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a400>,
#  'interpol': <gensim.models.keyedvectors.Vocab at 0x1dd369360f0>,
#  'cyclone': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0908>,
#  'surreal': <gensim.models.keyedvectors.Vocab at 0x1dd36bce278>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e518>,
#  'robs': <gensim.models.keyedvectors.Vocab at 0x1dd36936128>,
#  'nosy': <gensim.models.keyedvectors.Vocab at 0x1dd36936278>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x1dd36936208>,
#  'thieving': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e588>,
#  'clyde': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e5c0>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x1dd36b98a20>,
#  'renata': <gensim.models.keyedvectors.Vocab at 0x1dd36936400>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e5f8>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x1dd369d65f8>,
#  'wasn': <gensim.models.keyedvectors.Vocab at 0x1dd36a3ff60>,
#  'tara': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a438>,
#  'racially': <gensim.models.keyedvectors.Vocab at 0x1dd36ac7cf8>,
#  'hopper': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e630>,
#  'scofield': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a470>,
#  'affleck': <gensim.models.keyedvectors.Vocab at 0x1dd36ba09e8>,
#  'archie': <gensim.models.keyedvectors.Vocab at 0x1dd36bce940>,
#  'cornish': <gensim.models.keyedvectors.Vocab at 0x1dd36936240>,
#  'paradoxes': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e668>,
#  'napoleonic': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0a20>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a518>,
#  'stamped': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0a58>,
#  'jacob': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e6a0>,
#  'seclusion': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a550>,
#  'masks': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0a90>,
#  'outshines': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a588>,
#  'inherit': <gensim.models.keyedvectors.Vocab at 0x1dd36b15dd8>,
#  'oxford': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e6d8>,
#  'cds': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e710>,
#  'reserved': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e748>,
#  'scenarist': <gensim.models.keyedvectors.Vocab at 0x1dd36936470>,
#  'moves': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a5c0>,
#  'nikhil': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e780>,
#  'potemkin': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e7b8>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a5f8>,
#  'satana': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a630>,
#  'fallen': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e828>,
#  'charlies': <gensim.models.keyedvectors.Vocab at 0x1dd36936390>,
#  'pitka': <gensim.models.keyedvectors.Vocab at 0x1dd38486780>,
#  'gulager': <gensim.models.keyedvectors.Vocab at 0x1dd384bc828>,
#  'kin': <gensim.models.keyedvectors.Vocab at 0x1dd36936438>,
#  'lullaby': <gensim.models.keyedvectors.Vocab at 0x1dd36936cf8>,
#  'alludes': <gensim.models.keyedvectors.Vocab at 0x1dd36936cc0>,
#  'instructive': <gensim.models.keyedvectors.Vocab at 0x1dd36936da0>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x1dd369f8e48>,
#  'proto': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a668>,
#  'estranged': <gensim.models.keyedvectors.Vocab at 0x1dd36bd14a8>,
#  'crutch': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0be0>,
#  'serbian': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a6a0>,
#  'angeles': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e860>,
#  'toledo': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0c18>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0c50>,
#  'bestow': <gensim.models.keyedvectors.Vocab at 0x1dd36ac4400>,
#  'guiness': <gensim.models.keyedvectors.Vocab at 0x1dd36936d30>,
#  'jeanette': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a6d8>,
#  'leigh': <gensim.models.keyedvectors.Vocab at 0x1dd36afa400>,
#  'saddens': <gensim.models.keyedvectors.Vocab at 0x1dd36bd17b8>,
#  'jacks': <gensim.models.keyedvectors.Vocab at 0x1dd36a5d160>,
#  'swimming': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0c88>,
#  'perseverance': <gensim.models.keyedvectors.Vocab at 0x1dd36bd1940>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a748>,
#  'onions': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e898>,
#  'constructs': <gensim.models.keyedvectors.Vocab at 0x1dd36936e10>,
#  'bestiality': <gensim.models.keyedvectors.Vocab at 0x1dd38493ef0>,
#  'coney': <gensim.models.keyedvectors.Vocab at 0x1dd36936d68>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a780>,
#  'dreamworks': <gensim.models.keyedvectors.Vocab at 0x1dd36c53780>,
#  'poof': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e908>,
#  'mirror': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0cc0>,
#  'filed': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0d30>,
#  'mengele': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e940>,
#  'siamese': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0d68>,
#  'topaz': <gensim.models.keyedvectors.Vocab at 0x1dd36abc780>,
#  'ethos': <gensim.models.keyedvectors.Vocab at 0x1dd36bd1ef0>,
#  'decoration': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a7f0>,
#  'clowes': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0da0>,
#  'elegantly': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e9b0>,
#  'minimalism': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a828>,
#  'ewan': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a860>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x1dd36a9e9e8>,
#  'salo': <gensim.models.keyedvectors.Vocab at 0x1dd36ca3208>,
#  'histrionic': <gensim.models.keyedvectors.Vocab at 0x1dd3690ee48>,
#  'enhanced': <gensim.models.keyedvectors.Vocab at 0x1dd36936e48>,
#  'ins': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0dd8>,
#  'implanted': <gensim.models.keyedvectors.Vocab at 0x1dd384b1c50>,
#  'alexis': <gensim.models.keyedvectors.Vocab at 0x1dd36a6a128>,
#  'pointy': <gensim.models.keyedvectors.Vocab at 0x1dd36936e80>,
#  'corleone': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a898>,
#  'jumper': <gensim.models.keyedvectors.Vocab at 0x1dd36936ef0>,
#  'solomon': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0e10>,
#  'freight': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ea20>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x1dd36936f60>,
#  'swore': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a908>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x1dd36bd3748>,
#  'gallons': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ea58>,
#  'brigid': <gensim.models.keyedvectors.Vocab at 0x1dd36a9ea90>,
#  'sergei': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0e80>,
#  'sancho': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a978>,
#  'garbage': <gensim.models.keyedvectors.Vocab at 0x1dd36a943c8>,
#  'earns': <gensim.models.keyedvectors.Vocab at 0x1dd36a9eac8>,
#  'actresses': <gensim.models.keyedvectors.Vocab at 0x1dd36a9eb00>,
#  'undressed': <gensim.models.keyedvectors.Vocab at 0x1dd36a9eb38>,
#  'horner': <gensim.models.keyedvectors.Vocab at 0x1dd36936f98>,
#  'reprises': <gensim.models.keyedvectors.Vocab at 0x1dd369e3828>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x1dd36ba0f28>,
#  'cleef': <gensim.models.keyedvectors.Vocab at 0x1dd36936fd0>,
#  'tickets': <gensim.models.keyedvectors.Vocab at 0x1dd36b28908>,
#  'podium': <gensim.models.keyedvectors.Vocab at 0x1dd36c7a9e8>,
#  'paean': <gensim.models.keyedvectors.Vocab at 0x1dd36c7aa20>,
#  'flown': <gensim.models.keyedvectors.Vocab at 0x1dd369e3860>,
#  'besieged': <gensim.models.keyedvectors.Vocab at 0x1dd043f5cf8>,
#  'jacko': <gensim.models.keyedvectors.Vocab at 0x1dd369c3470>,
#  'tchaikovsky': <gensim.models.keyedvectors.Vocab at 0x1dd043f5908>,
#  ...}

# %% [markdown]
# Get an embedding for a word

# %%
model.wv['flower']
# Out:
# array([ 0.37915838,  0.09372403,  0.0262548 , -1.17967749,  0.39919809,
#        -0.50871468,  0.46438596,  0.09218451, -0.03408242,  0.15108852,
#         0.41516727,  1.12218118,  0.93676776,  0.22250989,  1.01879609,
#         1.34593356,  0.2620495 ,  0.24139282,  0.99214309,  0.91421306,
#        -0.23351651, -0.29771161,  0.74494773,  1.08225477, -0.04539989,
#         0.27483591,  0.00826408, -0.55425483, -0.44391334, -0.92362022,
#        -0.84691477,  1.1921947 , -0.67792529,  0.69149143, -0.3181636 ,
#        -0.23127717,  0.37454739, -0.76166487,  0.36729097,  0.98324329,
#        -1.54302824,  0.94953352, -2.00399041,  0.09720147,  0.02581038,
#         0.49339962,  0.85171854, -0.50338542,  0.55421662, -0.53529894], dtype=float32)

# %% [markdown]
# Saving the model

# %%
model.save('word2vec-movie-50')
# Out:
# 2018-05-04 14:25:24,511 : INFO : saving Word2Vec object under word2vec-movie-50, separately None
# 2018-05-04 14:25:24,519 : INFO : not storing attribute vectors_norm
# 2018-05-04 14:25:24,526 : INFO : not storing attribute cum_table
# 2018-05-04 14:25:25,144 : INFO : saved word2vec-movie-50

# %% [markdown]
# Finding Words which have similar meaning

# %%
model.wv.most_similar('fear')
# Out:
# 2018-05-04 14:25:35,405 : INFO : precomputing L2-norms of word weight vectors
# [('hatred', 0.7750701308250427),
#  ('cruelty', 0.7367026805877686),
#  ('pain', 0.7201778292655945),
#  ('misery', 0.7148659825325012),
#  ('humanity', 0.7008926868438721),
#  ('confusion', 0.7002967000007629),
#  ('anguish', 0.6962993741035461),
#  ('loneliness', 0.6903893351554871),
#  ('guilt', 0.6878209114074707),
#  ('frustration', 0.6854299306869507)]

# %% [markdown]
# Find the Word which is not like others

# %%
model.doesnt_match("man king child queen".split())
# Out:
# C:\Users\swamy\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 'king'

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# C:\Users\swamy\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('scientist', 0.6305267810821533),
#  ('nemesis', 0.5564342141151428),
#  ('warlord', 0.5396575927734375),
#  ('master', 0.5392469167709351),
#  ('soldier', 0.5374979972839355),
#  ('buio', 0.5320484638214111),
#  ('son', 0.5183924436569214),
#  ('golgo', 0.5137350559234619),
#  ('toulon', 0.5130910277366638),
#  ('maker', 0.509076714515686)]

# %% [markdown]
# Loading a model from Memory

# %%
model = gensim.models.Word2Vec.load('word2vec-movie-50')
# Out:
# 2018-05-04 14:26:04,036 : INFO : loading Word2Vec object from word2vec-movie-50
# 2018-05-04 14:26:04,423 : INFO : loading wv recursively from word2vec-movie-50.wv.* with mmap=None
# 2018-05-04 14:26:04,427 : INFO : setting ignored attribute vectors_norm to None
# 2018-05-04 14:26:04,435 : INFO : loading vocabulary recursively from word2vec-movie-50.vocabulary.* with mmap=None
# 2018-05-04 14:26:04,455 : INFO : loading trainables recursively from word2vec-movie-50.trainables.* with mmap=None
# 2018-05-04 14:26:04,473 : INFO : setting ignored attribute cum_table to None
# 2018-05-04 14:26:04,491 : INFO : loaded word2vec-movie-50
